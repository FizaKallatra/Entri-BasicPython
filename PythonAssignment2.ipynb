# %% [markdown]
# <a href="https://colab.research.google.com/github/FizaKallatra/Entri-BasicPython/blob/main/PythonAssignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.Create agelist
age_list=[24,25,26,27,28]
print(age_list)
# Out:
# [24, 25, 26, 27, 28]

# %%
name_list=["Riya","Priya","Arun","Ravi","Sid"]
print(name_list)
# Out:
# ['Riya', 'Priya', 'Arun', 'Ravi', 'Sid']

# %%
#2.List Operations
#a.Append the string "Yazhini" to name_list.
name_list.append("Yazhini")
print(name_list)
# Out:
# ['Riya', 'Priya', 'Arun', 'Ravi', 'Sid', 'Yazhini']

# %%
#b. Insert the element 30 at index 2 in age_list.
age_list.insert(1,30)
print(age_list)
# Out:
# [24, 30, 25, 26, 27, 28]

# %%
#c. Remove the string "Yazhini" from name_list.
name_list.pop()
print(name_list)
# Out:
# ['Riya', 'Priya', 'Arun', 'Ravi', 'Sid']

# %%
#d. Pop the last element from age_list.
age_list.pop()
print(age_list)
# Out:
# [24, 30, 25, 26, 27]

# %%
#e. Extend the age_list with additional ages [29, 30, 26].
age_list.extend([29,30,26])
print(age_list)
# Out:
# [24, 30, 25, 26, 27, 29, 30, 26]

# %%
#f. Sort age_list in descending order.
age_list.sort(reverse=True)
print(age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %%
#g. Find Max age, Min age and sum of all ages from age_list.
print("Max age:", max(age_list))
print("Min age:", min(age_list))
print("Sum of all ages:", sum(age_list))
# Out:
# Max age: 30
# Min age: 24
# Sum of all ages: 217

# %%
#3. Accessing List Elements:
#a. Print the first element of name_list.
print(name_list[0])
# Out:
# Riya

# %%
#b. Print the last element of name_list.
print(name_list[-1])
# Out:
# Sid

# %%
#c. Print the elements from index 2 to index 4 in name_list.
print(name_list[2:5])
# Out:
# ['Arun', 'Ravi', 'Sid']

# %%
#d. Print the elements of name_list in reverse order.
print(name_list[::-1])
# Out:
# ['Sid', 'Ravi', 'Arun', 'Priya', 'Riya']

# %%
#Dictionary (Creation, Modification and Access):
#a. Create a dictionary named student_marks that maps the names of five students to their marks (use scale of from 0 to 100).
student_marks = {
    "Riya": 85,
    "Priya": 92,
    "Arun": 78,
    "Ravi": 95,
    "Sid": 88
}
print(student_marks)
# Out:
# {'Riya': 85, 'Priya': 92, 'Arun': 78, 'Ravi': 95, 'Sid': 88}

# %%
#b. Access and print the mark of a specific student, of your choice.
print("Priya's Mark:",student_marks["Priya"])
# Out:
# Priya's Mark: 92

# %%
#c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
student_marks["Janani"]=80
print(student_marks)
# Out:
# {'Riya': 85, 'Priya': 92, 'Arun': 78, 'Ravi': 95, 'Sid': 88, 'Janani': 80}

# %%
#d. Update the mark of any one older student to 82.
student_marks["Janani"]=82
print(student_marks)
# Out:
# {'Riya': 85, 'Priya': 92, 'Arun': 78, 'Ravi': 95, 'Sid': 88, 'Janani': 82}

# %%
#e. Use the keys(), values(), and items() methods to print all keys, values, and key-value pairs in the student_marks dictionary.
print(student_marks.keys())
print(student_marks.values())
print(student_marks.items())
# Out:
# dict_keys(['Riya', 'Priya', 'Arun', 'Ravi', 'Sid', 'Janani'])
# dict_values([85, 92, 78, 95, 88, 82])
# dict_items([('Riya', 85), ('Priya', 92), ('Arun', 78), ('Ravi', 95), ('Sid', 88), ('Janani', 82)])

# %%
#Sets (Operations):
#a. Create a set called my_set with following values:['a','e','i','o','u','a','a','i']
my_set={'a','e','i','o','u','a','a','i'}
print(my_set)
#A set is a collection of unique, unordered items.Therefore duplicates are not printed and the provided output is unordered.
# Out:
# {'u', 'i', 'e', 'a', 'o'}

# %%
#b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.
my_set[4] = 's'
print(my_set)

#'set' object does not support item assignment.Since set is unordered,index cant retrieve any result.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2619/4029197657.py in <cell line: 0>()
#       1 #b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.
# ----> 2 my_set[4] = 's'
#       3 print(my_set)
#
# TypeError: 'set' object does not support item assignment

# %%
#c. Create two sets: set1 with values: {1, 3, 5, 7, 9} set2 with values: {2, 3, 5, 8, 10}
set1={1,3,5,7,9}
set2={2,3,5,8,10}
print(set1)
print(set2)
# Out:
# {1, 3, 5, 7, 9}
# {2, 3, 5, 8, 10}

# %%
#d. Compute and print the union and intersection of set1 and set2.
print("Union of set1 and set2:",set1|set2)
print("Intersection of set1 and set2:",set1.intersection(set2))
# Out:
# Union of set1 and set2: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection of set1 and set2: {3, 5}

# %%
#Operators & Conditional Statements :
#1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
print("Enter Score(0-10):")
score=int(input())
print("The given score is",score)
# Out:
# Enter Score(0-10):
# 8
# The given score is 8

# %%
#2. Find the performance category based on the input score using following criteria:
if(score>7):
  performance_category="Above Average.Good Job"
elif(score>=4 and score<=7):
  performance_category="Average.Need to Improve"
else:
  performance_category="Below Average.Practise Harder"

# %%
#3. Output: Print the Performance category
print("Performance Category:",performance_category)
# Out:
# Performance Category: Above Average.Good Job
