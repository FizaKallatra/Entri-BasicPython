# %%
print("Enter your name:\n")
string1="Hello"
string2=str(input())
print(string1,string2)
# Out:
# Enter your name:
#
# Fiza
# Hello Fiza

# %%
string3=",Welcome to python Programming"
print(string1,string2,string3)
string4=string1+string2+string3
print(string4)
# Out:
# Hello Fiza ,Welcome to python Programming
# HelloFiza,Welcome to python Programming

# %%
print(string4[0])                          # a. Print the first character of the string.
# Out:
# H

# %%
print(string4[-1])                         #b. Print the last character of the string.
# Out:
# g

# %%
print(string4[0:5])                        #c. Print the first 5 characters of the string.
# Out:
# Hello

# %%
print(string4[-11:])                     #d. Print the last 11 characters of the string.
# Out:
# Programming

# %%
print(string4[::-1])                       #e. Print the string in reverse.
# Out:
# gnimmargorP nohtyp ot emocleW,aziFolleH

# %%
print(string4[-18:-12])                    #f. Use slicing and print the word “Python” from the existing string.
# Out:
# python

# %%
strM="Python beginner tutorial"
print(strM.upper())                               #a. Convert the sentence to uppercase.
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
print(strM.lower())                               #b. Convert the sentence to lowercase.
# Out:
# python beginner tutorial

# %%
print(strM.title())                               #c. Use Capitalize and return the sentence to the original input form.
# Out:
# Python Beginner Tutorial

# %%
print(strM.count("t"))                            #d.Count the total number of occurrences of character ‘t’ in the string.
# Out:
# 3

# %%
print(strM.replace("Python","Machine Learning"))  #e. Replace all occurrences of “Python” with “Machine Learning” in the input string
# Out:
# Machine Learning beginner tutorial

# %%
t1=(10,20,30)
t2=(40,50,60)
t_combine=t1+t2                         #a. Concatenate the two tuples and store it in “t_combine”
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine * 3)                    #b. Repeat the elements of “t_combine” 3 times
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])                     #c. Access the 3rd element from “t_combine”
# Out:
# 30

# %%
print(t_combine[0:3])                   #d. Access the first three elements from “t_combine”
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])                   #e. Access the last three elements from “t_combine”
# Out:
# (40, 50, 60)
